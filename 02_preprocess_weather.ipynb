# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/weather_hist_iowa.csv")
data
# Out:
#                       time  temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt  \
# 0      2021-01-01 00:00:00 -10.0 -10.0  100.0   NaN   NaN    NaN   NaN   NaN
# 1      2021-01-01 01:00:00 -10.0 -10.0  100.0   0.0   NaN  100.0  13.0   NaN
# 2      2021-01-01 02:00:00  -8.0  -8.0  100.0   0.0   NaN  130.0  14.8   NaN
# 3      2021-01-01 03:00:00  -6.0  -6.0  100.0   0.0   NaN  140.0  14.8   NaN
# 4      2021-01-01 04:00:00  -6.0  -6.0  100.0   0.0   NaN  130.0  13.0   NaN
# ...                    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 26276  2023-12-31 20:00:00  -1.0  -1.0  100.0   0.0   NaN  320.0  27.7   NaN
# 26277  2023-12-31 21:00:00   0.0   0.0  100.0   0.0   NaN  330.0  22.3   NaN
# 26278  2023-12-31 22:00:00  -1.0  -1.0  100.0   0.0   NaN  330.0  27.7   NaN
# 26279  2023-12-31 23:00:00  -1.0  -1.0  100.0   0.0   NaN  340.0  20.5   NaN
# 26280  2024-01-01 00:00:00  -1.0  -2.0   93.0   0.0   NaN  350.0  20.0   NaN
#
#          pres  tsun  coco
# 0         NaN   NaN   5.0
# 1      1025.5   NaN   5.0
# 2      1025.7   NaN   5.0
# 3      1026.2   NaN   NaN
# 4      1026.0   NaN   5.0
# ...       ...   ...   ...
# 26276  1021.0   NaN   3.0
# 26277  1022.0   NaN   3.0
# 26278  1022.0   NaN   3.0
# 26279  1023.0   NaN   3.0
# 26280  1024.0   NaN   3.0
#
# [26281 rows x 12 columns]

# %%
data.describe()
# Out:
#                temp          dwpt          rhum          prcp  snow  \
# count  26281.000000  26281.000000  26281.000000  26280.000000   0.0
# mean      10.488585      5.760702     76.544310      0.118634   NaN
# std       12.257682     11.619882     21.683203      0.786090   NaN
# min      -28.000000    -31.900000     13.000000      0.000000   NaN
# 25%        1.000000     -2.100000     61.000000      0.000000   NaN
# 50%       11.000000      5.000000     81.000000      0.000000   NaN
# 75%       21.000000     16.000000    100.000000      0.000000   NaN
# max       36.000000     31.000000    100.000000     34.800000   NaN
#
#                wdir          wspd  wpgt          pres  tsun          coco
# count  26280.000000  26280.000000   0.0  26280.000000   0.0  15625.000000
# mean     182.531735     16.116115   NaN   1016.225658   NaN      3.092608
# std      107.058771      8.984260   NaN      7.519832   NaN      2.326919
# min        0.000000      0.000000   NaN    982.000000   NaN      1.000000
# 25%      100.000000      9.400000   NaN   1012.000000   NaN      1.000000
# 50%      180.000000     14.800000   NaN   1016.000000   NaN      3.000000
# 75%      280.000000     22.300000   NaN   1021.000000   NaN      5.000000
# max      360.000000     66.600000   NaN   1043.300000   NaN     18.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    26281 non-null  object
#  1   temp    26281 non-null  float64
#  2   dwpt    26281 non-null  float64
#  3   rhum    26281 non-null  float64
#  4   prcp    26280 non-null  float64
#  5   snow    0 non-null      float64
#  6   wdir    26280 non-null  float64
#  7   wspd    26280 non-null  float64
#  8   wpgt    0 non-null      float64
#  9   pres    26280 non-null  float64
#  10  tsun    0 non-null      float64
#  11  coco    15625 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 2.4+ MB

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'dwpt'}>,
#         <Axes: title={'center': 'rhum'}>],
#        [<Axes: title={'center': 'prcp'}>,
#         <Axes: title={'center': 'snow'}>,
#         <Axes: title={'center': 'wdir'}>],
#        [<Axes: title={'center': 'wspd'}>,
#         <Axes: title={'center': 'wpgt'}>,
#         <Axes: title={'center': 'pres'}>],
#        [<Axes: title={'center': 'tsun'}>,
#         <Axes: title={'center': 'coco'}>, <Axes: >]], dtype=object)

# %%
data.isnull().sum()
# Out:
# time        0
# temp        0
# dwpt        0
# rhum        0
# prcp        1
# snow    26281
# wdir        1
# wspd        1
# wpgt    26281
# pres        1
# tsun    26281
# coco    10656
# dtype: int64

# %%
data = data.drop(columns=['snow', 'wpgt', 'tsun', 'coco'])
data
# Out:
#                       time  temp  dwpt   rhum  prcp   wdir  wspd    pres
# 0      2021-01-01 00:00:00 -10.0 -10.0  100.0   NaN    NaN   NaN     NaN
# 1      2021-01-01 01:00:00 -10.0 -10.0  100.0   0.0  100.0  13.0  1025.5
# 2      2021-01-01 02:00:00  -8.0  -8.0  100.0   0.0  130.0  14.8  1025.7
# 3      2021-01-01 03:00:00  -6.0  -6.0  100.0   0.0  140.0  14.8  1026.2
# 4      2021-01-01 04:00:00  -6.0  -6.0  100.0   0.0  130.0  13.0  1026.0
# ...                    ...   ...   ...    ...   ...    ...   ...     ...
# 26276  2023-12-31 20:00:00  -1.0  -1.0  100.0   0.0  320.0  27.7  1021.0
# 26277  2023-12-31 21:00:00   0.0   0.0  100.0   0.0  330.0  22.3  1022.0
# 26278  2023-12-31 22:00:00  -1.0  -1.0  100.0   0.0  330.0  27.7  1022.0
# 26279  2023-12-31 23:00:00  -1.0  -1.0  100.0   0.0  340.0  20.5  1023.0
# 26280  2024-01-01 00:00:00  -1.0  -2.0   93.0   0.0  350.0  20.0  1024.0
#
# [26281 rows x 8 columns]

# %%
# Check and handle missing values for all types
for col in data.columns:
    if data[col].dtype == 'float64':
        data[col].fillna(data[col].mean(), inplace=True)
# Out:
# C:\Users\gevsi\AppData\Local\Temp\ipykernel_12292\908293033.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# time    0
# temp    0
# dwpt    0
# rhum    0
# prcp    0
# wdir    0
# wspd    0
# pres    0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#                       time  temp  dwpt   rhum      prcp        wdir  \
# 0      2021-01-01 00:00:00 -10.0 -10.0  100.0  0.118634  182.531735
# 1      2021-01-01 01:00:00 -10.0 -10.0  100.0  0.000000  100.000000
# 2      2021-01-01 02:00:00  -8.0  -8.0  100.0  0.000000  130.000000
# 3      2021-01-01 03:00:00  -6.0  -6.0  100.0  0.000000  140.000000
# 4      2021-01-01 04:00:00  -6.0  -6.0  100.0  0.000000  130.000000
# ...                    ...   ...   ...    ...       ...         ...
# 26276  2023-12-31 20:00:00  -1.0  -1.0  100.0  0.000000  320.000000
# 26277  2023-12-31 21:00:00   0.0   0.0  100.0  0.000000  330.000000
# 26278  2023-12-31 22:00:00  -1.0  -1.0  100.0  0.000000  330.000000
# 26279  2023-12-31 23:00:00  -1.0  -1.0  100.0  0.000000  340.000000
# 26280  2024-01-01 00:00:00  -1.0  -2.0   93.0  0.000000  350.000000
#
#             wspd         pres
# 0      16.116115  1016.225658
# 1      13.000000  1025.500000
# 2      14.800000  1025.700000
# 3      14.800000  1026.200000
# 4      13.000000  1026.000000
# ...          ...          ...
# 26276  27.700000  1021.000000
# 26277  22.300000  1022.000000
# 26278  27.700000  1022.000000
# 26279  20.500000  1023.000000
# 26280  20.000000  1024.000000
#
# [26281 rows x 8 columns]

# %%
plt.figure()
sns.heatmap(data[['temp', 'dwpt', 'rhum', 'prcp', 'wdir', 'wspd', 'pres']].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
elec_data = pd.read_csv("data/MW_electricity_cleaned.csv")
elec_data
# Out:
#        Unnamed: 0 UTC Time at End of Hour  Net Generation (MW) from Coal  \
# 0               0     2021-01-01 06:00:00                        25367.0
# 1               1     2021-01-01 07:00:00                        24662.0
# 2               2     2021-01-01 08:00:00                        25365.0
# 3               3     2021-01-01 09:00:00                        24811.0
# 4               4     2021-01-01 10:00:00                        25041.0
# ...           ...                     ...                            ...
# 26269       26269     2023-12-31 19:00:00                        19663.0
# 26270       26270     2023-12-31 20:00:00                        19740.0
# 26271       26271     2023-12-31 21:00:00                        20145.0
# 26272       26272     2023-12-31 22:00:00                        21403.0
# 26273       26273     2023-12-31 23:00:00                        22887.0
#
#        Net Generation (MW) from Natural Gas  Net Generation (MW) from Nuclear  \
# 0                                   15999.0                           11534.0
# 1                                   16063.0                           11544.0
# 2                                   16057.0                           11555.0
# 3                                   15870.0                           11560.0
# 4                                   15755.0                           11565.0
# ...                                     ...                               ...
# 26269                               26718.0                            8205.0
# 26270                               26912.0                            8203.0
# 26271                               26794.0                            8204.0
# 26272                               27195.0                            8203.0
# 26273                               27978.0                            8202.0
#
#        Net Generation (MW) from All Petroleum Products  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 26269                                              NaN
# 26270                                              NaN
# 26271                                              NaN
# 26272                                              NaN
# 26273                                              NaN
#
#        Net Generation (MW) from Hydropower and Pumped Storage  \
# 0                                                  714.0
# 1                                                  664.0
# 2                                                  661.0
# 3                                                  664.0
# 4                                                  668.0
# ...                                                  ...
# 26269                                              811.0
# 26270                                              805.0
# 26271                                              802.0
# 26272                                              850.0
# 26273                                             1738.0
#
#        Net Generation (MW) from Solar  Net Generation (MW) from Wind  \
# 0                                 0.0                         9486.0
# 1                                 0.0                         8780.0
# 2                                 0.0                         6912.0
# 3                                 0.0                         5967.0
# 4                                 0.0                         5074.0
# ...                               ...                            ...
# 26269                          1060.0                        11799.0
# 26270                           976.0                        11074.0
# 26271                           825.0                        10717.0
# 26272                           541.0                        10181.0
# 26273                           152.0                         9150.0
#
#        Net Generation (MW) from Other
# 0                               840.0
# 1                               840.0
# 2                               839.0
# 3                               840.0
# 4                               844.0
# ...                               ...
# 26269                           330.0
# 26270                           332.0
# 26271                           340.0
# 26272                           344.0
# 26273                           358.0
#
# [26274 rows x 10 columns]

# %%
data = data.rename(columns={'time': 'UTC Time at End of Hour'})  

df_merged = pd.merge(elec_data, data, on='UTC Time at End of Hour', how='left')

df_merged
# Out:
#        Unnamed: 0 UTC Time at End of Hour  Net Generation (MW) from Coal  \
# 0               0     2021-01-01 06:00:00                        25367.0
# 1               1     2021-01-01 07:00:00                        24662.0
# 2               2     2021-01-01 08:00:00                        25365.0
# 3               3     2021-01-01 09:00:00                        24811.0
# 4               4     2021-01-01 10:00:00                        25041.0
# ...           ...                     ...                            ...
# 26269       26269     2023-12-31 19:00:00                        19663.0
# 26270       26270     2023-12-31 20:00:00                        19740.0
# 26271       26271     2023-12-31 21:00:00                        20145.0
# 26272       26272     2023-12-31 22:00:00                        21403.0
# 26273       26273     2023-12-31 23:00:00                        22887.0
#
#        Net Generation (MW) from Natural Gas  Net Generation (MW) from Nuclear  \
# 0                                   15999.0                           11534.0
# 1                                   16063.0                           11544.0
# 2                                   16057.0                           11555.0
# 3                                   15870.0                           11560.0
# 4                                   15755.0                           11565.0
# ...                                     ...                               ...
# 26269                               26718.0                            8205.0
# 26270                               26912.0                            8203.0
# 26271                               26794.0                            8204.0
# 26272                               27195.0                            8203.0
# 26273                               27978.0                            8202.0
#
#        Net Generation (MW) from All Petroleum Products  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 26269                                              NaN
# 26270                                              NaN
# 26271                                              NaN
# 26272                                              NaN
# 26273                                              NaN
#
#        Net Generation (MW) from Hydropower and Pumped Storage  \
# 0                                                  714.0
# 1                                                  664.0
# 2                                                  661.0
# 3                                                  664.0
# 4                                                  668.0
# ...                                                  ...
# 26269                                              811.0
# 26270                                              805.0
# 26271                                              802.0
# 26272                                              850.0
# 26273                                             1738.0
#
#        Net Generation (MW) from Solar  Net Generation (MW) from Wind  \
# 0                                 0.0                         9486.0
# 1                                 0.0                         8780.0
# 2                                 0.0                         6912.0
# 3                                 0.0                         5967.0
# 4                                 0.0                         5074.0
# ...                               ...                            ...
# 26269                          1060.0                        11799.0
# 26270                           976.0                        11074.0
# 26271                           825.0                        10717.0
# 26272                           541.0                        10181.0
# 26273                           152.0                         9150.0
#
#        Net Generation (MW) from Other  temp  dwpt   rhum  prcp   wdir  wspd  \
# 0                               840.0  -6.0  -6.0  100.0   0.0  130.0  20.5
# 1                               840.0  -6.0  -6.0  100.0   0.0  100.0   9.4
# 2                               839.0  -6.0  -6.0  100.0   0.0  110.0  13.0
# 3                               840.0  -6.0  -6.0  100.0   0.0   90.0  16.6
# 4                               844.0  -6.0  -6.0  100.0   0.0   80.0  13.0
# ...                               ...   ...   ...    ...   ...    ...   ...
# 26269                           330.0   0.0  -1.0   93.0   0.0  330.0  29.5
# 26270                           332.0  -1.0  -1.0  100.0   0.0  320.0  27.7
# 26271                           340.0   0.0   0.0  100.0   0.0  330.0  22.3
# 26272                           344.0  -1.0  -1.0  100.0   0.0  330.0  27.7
# 26273                           358.0  -1.0  -1.0  100.0   0.0  340.0  20.5
#
#          pres
# 0      1025.3
# 1      1025.2
# 2      1025.0
# 3      1024.5
# 4      1024.1
# ...       ...
# 26269  1020.0
# 26270  1021.0
# 26271  1022.0
# 26272  1022.0
# 26273  1023.0
#
# [26274 rows x 17 columns]

# %%
# Define the columns for each DataFrame
columns_non_renewables = ['UTC Time at End of Hour', 'Net Generation (MW) from Coal', 'Net Generation (MW) from Natural Gas', 'Net Generation (MW) from Nuclear', 'Net Generation (MW) from All Petroleum Products']
columns_renewables = ['UTC Time at End of Hour', 'Net Generation (MW) from Hydropower and Pumped Storage', 'Net Generation (MW) from Solar', 'Net Generation (MW) from Wind', 'Net Generation (MW) from Other', 'temp', 'dwpt', 'rhum', 'prcp', 'wdir', 'wspd', 'pres']

non_renewables = df_merged[columns_non_renewables]
renewables = df_merged[columns_renewables]

# %%
non_renewables
# Out:
#       UTC Time at End of Hour  Net Generation (MW) from Coal  \
# 0         2021-01-01 06:00:00                        25367.0
# 1         2021-01-01 07:00:00                        24662.0
# 2         2021-01-01 08:00:00                        25365.0
# 3         2021-01-01 09:00:00                        24811.0
# 4         2021-01-01 10:00:00                        25041.0
# ...                       ...                            ...
# 26269     2023-12-31 19:00:00                        19663.0
# 26270     2023-12-31 20:00:00                        19740.0
# 26271     2023-12-31 21:00:00                        20145.0
# 26272     2023-12-31 22:00:00                        21403.0
# 26273     2023-12-31 23:00:00                        22887.0
#
#        Net Generation (MW) from Natural Gas  Net Generation (MW) from Nuclear  \
# 0                                   15999.0                           11534.0
# 1                                   16063.0                           11544.0
# 2                                   16057.0                           11555.0
# 3                                   15870.0                           11560.0
# 4                                   15755.0                           11565.0
# ...                                     ...                               ...
# 26269                               26718.0                            8205.0
# 26270                               26912.0                            8203.0
# 26271                               26794.0                            8204.0
# 26272                               27195.0                            8203.0
# 26273                               27978.0                            8202.0
#
#        Net Generation (MW) from All Petroleum Products
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 26269                                              NaN
# 26270                                              NaN
# 26271                                              NaN
# 26272                                              NaN
# 26273                                              NaN
#
# [26274 rows x 5 columns]

# %%
renewables
# Out:
#       UTC Time at End of Hour  \
# 0         2021-01-01 06:00:00
# 1         2021-01-01 07:00:00
# 2         2021-01-01 08:00:00
# 3         2021-01-01 09:00:00
# 4         2021-01-01 10:00:00
# ...                       ...
# 26269     2023-12-31 19:00:00
# 26270     2023-12-31 20:00:00
# 26271     2023-12-31 21:00:00
# 26272     2023-12-31 22:00:00
# 26273     2023-12-31 23:00:00
#
#        Net Generation (MW) from Hydropower and Pumped Storage  \
# 0                                                  714.0
# 1                                                  664.0
# 2                                                  661.0
# 3                                                  664.0
# 4                                                  668.0
# ...                                                  ...
# 26269                                              811.0
# 26270                                              805.0
# 26271                                              802.0
# 26272                                              850.0
# 26273                                             1738.0
#
#        Net Generation (MW) from Solar  Net Generation (MW) from Wind  \
# 0                                 0.0                         9486.0
# 1                                 0.0                         8780.0
# 2                                 0.0                         6912.0
# 3                                 0.0                         5967.0
# 4                                 0.0                         5074.0
# ...                               ...                            ...
# 26269                          1060.0                        11799.0
# 26270                           976.0                        11074.0
# 26271                           825.0                        10717.0
# 26272                           541.0                        10181.0
# 26273                           152.0                         9150.0
#
#        Net Generation (MW) from Other  temp  dwpt   rhum  prcp   wdir  wspd  \
# 0                               840.0  -6.0  -6.0  100.0   0.0  130.0  20.5
# 1                               840.0  -6.0  -6.0  100.0   0.0  100.0   9.4
# 2                               839.0  -6.0  -6.0  100.0   0.0  110.0  13.0
# 3                               840.0  -6.0  -6.0  100.0   0.0   90.0  16.6
# 4                               844.0  -6.0  -6.0  100.0   0.0   80.0  13.0
# ...                               ...   ...   ...    ...   ...    ...   ...
# 26269                           330.0   0.0  -1.0   93.0   0.0  330.0  29.5
# 26270                           332.0  -1.0  -1.0  100.0   0.0  320.0  27.7
# 26271                           340.0   0.0   0.0  100.0   0.0  330.0  22.3
# 26272                           344.0  -1.0  -1.0  100.0   0.0  330.0  27.7
# 26273                           358.0  -1.0  -1.0  100.0   0.0  340.0  20.5
#
#          pres
# 0      1025.3
# 1      1025.2
# 2      1025.0
# 3      1024.5
# 4      1024.1
# ...       ...
# 26269  1020.0
# 26270  1021.0
# 26271  1022.0
# 26272  1022.0
# 26273  1023.0
#
# [26274 rows x 12 columns]
